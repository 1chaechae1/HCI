# %%
import csv
ac = 0
ab = 0
"""
강원 = 0
경기 = 1
경남 = 2
경북 = 3
광주 = 4
대구 = 5
부산 = 6
서울 = 7
울산 = 8
인천 = 9
전남 = 10
전북 = 11
제주 = 12
충남 = 13
충북 = 14

"""

card = [[0 for j in range(100)] for i in range(2)]



f = open('카드데이터) 광역시도별_음식점_1718_통계.csv',encoding='UTF8')
data = csv.reader(f)
header = next(data)
for row in data:
    """
    if max_temp < float(row[-1]):
        max_date = row[0]
        max_temp = float(row[-1])
    """
    if row[0] == "강원":
        card[0][0] = row[0]
        card[1][0] = card[1][0]+float(row[-2])
        
    elif row[0] == "경기":
        card[0][1] = row[0]
        card[1][1] = card[1][1]+float(row[-2])
        
    elif row[0] == "경남":
        card[0][2] = row[0]
        card[1][2] = card[1][2]+float(row[-2])
        
    elif row[0] == "경북":
        card[0][3] = row[0]
        card[1][3] = card[1][3]+float(row[-2])
        
    elif row[0] == "광주":
        card[0][4] = row[0]
        card[1][4] = card[1][4]+float(row[-2])     
        
    elif row[0] == "대구":
        card[0][5] = row[0]
        card[1][5] = card[1][5]+float(row[-2])    
              
    elif row[0] == "부산":
        card[0][6] = row[0]
        card[1][6] = card[1][6]+float(row[-2])     
        
    elif row[0] == "서울":
        card[0][7] = row[0]
        card[1][7] = card[1][7]+float(row[-2])  
        
    elif row[0] == "울산":
        card[0][8] = row[0]
        card[1][8] = card[1][8]+float(row[-2])    
        
    elif row[0] == "인천":
        card[0][9] = row[0]
        card[1][9] = card[1][9]+float(row[-2])     
    
    elif row[0] == "전남":
        card[0][10] = row[0]
        card[1][10] = card[1][10]+float(row[-2])
    
    elif row[0] == "전북":
        card[0][11] = row[0]
        card[1][11] = card[1][11]+float(row[-2]) 
    
    elif row[0] == "제주":
        card[0][12] = row[0]
        card[1][12] = card[1][12]+float(row[-2]) 
    
    elif row[0] == "충남":
        card[0][13] = row[0]
        card[1][13] = card[1][13]+float(row[-2])
        
    elif row[0] == "충북":
        card[0][14] = row[0]
        card[1][14] = card[1][14]+float(row[-2])

for i in range(0,15):
    
    for  j in range(0,15):
        if(card[1][j]<card[1][j+1]):
              
            ab = card[0][j]
            card[0][j] = card[0][j+1]
            card[0][j+1] = ab
       
      
            ac = card[1][j]
            card[1][j] = card[1][j+1]
            card[1][j+1] = ac



        
        
        
        
 
for i in range(0,15):
    print(i+1,card[0][i],card[1][i])
    
    

 
    
f.close()
# Out:
# 1 서울 48186604978856.31
# 2 경기 45602250705757.44
# 3 부산 9904958981561.26
# 4 인천 9776775883429.838
# 5 경남 7953368101824.851
# 6 충남 6169947556830.741
# 7 강원 6001222917701.97
# 8 경북 5835996178608.499
# 9 대구 5709426745858.801
# 10 충북 5484154186977.609
# 11 전북 4251438927259.78
# 12 전남 4105149006848.43
# 13 광주 4016126536721.6094
# 14 울산 3438986122193.01
# 15 제주 3394063684318.9
